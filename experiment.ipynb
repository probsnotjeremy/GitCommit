# %%
import json
import tempfile
import shutil
import time
import datetime
import os
import random
from datasets import Dataset
from dataset_prep import overlap_percent, semantic_percent, dataset_split
from model_setup import send_to_llm
from transformers import Trainer, TrainingArguments
from model_setup import model, lora_model, tokenizer, tokenized_dataset



train_dataset: Dataset = tokenized_dataset["query"]
eval_dataset: Dataset = tokenized_dataset["answers"]

# --------------------------
# Trainer
# --------------------------

training_args = TrainingArguments(
    output_dir="./qlora_phi2",
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,  # effective batch size = 8
    learning_rate=2e-4,
    num_train_epochs=1,             # bump later if GPU allows
    logging_dir="./logs",
    save_strategy="epoch",
    bf16=False,                     # GTX 1070 doesn’t support bf16
    fp16=True,                      # you can use fp16 instead
    optim="paged_adamw_8bit",       # bitsandbytes optimizer
)

trainer = Trainer(
    model=lora_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)


# --------------------------
# Experiment helpers
# --------------------------

def run_experiment(dataset_split, n=20):

    idxs = random.sample(range(len(dataset_split)), min(n, len(dataset_split)))
    subset = [dataset_split[i] for i in idxs]  # only N rows, lazy load

    start_time = time.time()

    results = []

    for i, row in enumerate(subset):
        q, a = row["query"], row["answer"]
        resp = send_to_llm(q)
        overlap_score = overlap_percent(a, resp, use_synonyms=True)
        semantic_score = semantic_percent(a, resp)

        results.append({
            "id": i,
            "question": q,
            "expected_answer": a,
            "llm_response": resp,
            "overlap_percent": round(overlap_score, 2),
            "semantic_percent": round(semantic_score, 2)
        })

    duration = time.time() - start_time
    return results, duration


def save_results(results, duration, filename="TestResults.json"):
    if os.path.exists(filename):
        with open(filename, "r") as f:
            all_results = json.load(f)
    else:
        all_results = []

    test_number = len(all_results) + 1
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Compute averages
    avg_overlap = sum(r["overlap_percent"] for r in results) / len(results)
    avg_semantic = sum(r["semantic_percent"] for r in results) / len(results)

    all_results.append({
        "test_number": test_number,
        "timestamp": timestamp,
        "duration_seconds": round(duration, 2),
        "n_questions": len(results),
        "avg_overlap": round(avg_overlap, 2),
        "avg_semantic": round(avg_semantic, 2),
        "results": results
    })


    # Write to a temp file first
    with tempfile.NamedTemporaryFile("w", delete=False) as tmp:
        json.dump(all_results, tmp, indent=2)
        tempname = tmp.name

    shutil.move(tempname, filename)

    print(f"Saved Test #{test_number} ({round(duration,2)}s) with {len(results)} results to {filename}")

# --------------------------
# Main
# --------------------------
def main(n=20):
    results, duration = run_experiment(dataset_split, n=n)
    save_results(results, duration)

if __name__ == "__main__":
    main()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Map:   0%|          | 0/100231 [00:00<?, ? examples/s]
# QLoRA-ready model initialized.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 17
#      12 from model_setup import model, lora_model, tokenizer, tokenized_dataset
#      16 train_dataset: Dataset = tokenized_dataset["train"]
# ---> 17 eval_dataset: Dataset = tokenized_dataset["validation"]
#      19 # --------------------------
#      20 # Trainer
#      21 # --------------------------
#      23 training_args = TrainingArguments(
#      24     output_dir="./qlora_phi2",
#      25     per_device_train_batch_size=1,
#    (...)     33     optim="paged_adamw_8bit",       # bitsandbytes optimizer
#      34 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\dataset_dict.py:82, in DatasetDict.__getitem__(self, k)
#      80 def __getitem__(self, k) -> Dataset:
#      81     if isinstance(k, (str, NamedSplit)) or len(self) == 0:
# ---> 82         return super().__getitem__(k)
#      83     else:
#      84         available_suggested_splits = [
#      85             split for split in (Split.TRAIN, Split.TEST, Split.VALIDATION) if split in self
#      86         ]
#
# KeyError: 'validation'

# %%
import pandas as pd
import json

# --------------------------
# Table Results
# --------------------------

def summarize_results(df):
    summary = (
        df.groupby("test_number")
          .agg(
              n_questions=("question", "count"),
              avg_overlap=("overlap_percent", "mean"),
              avg_semantic=("semantic_percent", "mean"),
              duration_seconds=("duration_seconds", "first"),
              timestamp=("timestamp", "first")
          )
          .reset_index()
    )
    return summary


def load_results_as_table(filename="TestResults.json"):
    with open(filename, "r") as f:
        all_results = json.load(f)

    # Flatten into a list of rows
    rows = []
    for test in all_results:
        for r in test["results"]:
            rows.append({
                "test_number": test["test_number"],
                "timestamp": test["timestamp"],
                "duration_seconds": test["duration_seconds"],
                "question": r["question"],
                "expected_answer": r["expected_answer"],
                "llm_response": r["llm_response"],
                "overlap_percent": r["overlap_percent"],
                "semantic_percent": r["semantic_percent"]
            })

    df = pd.DataFrame(rows)
    return df

df = load_results_as_table()
summary = summarize_results(df)
print(summary)
df.tail(20)
# Out:
#    test_number  n_questions  avg_overlap  avg_semantic  duration_seconds  \
# 0            1            5       7.1420       41.6980             15.34
# 1            2           20      18.2995       54.9925            160.29
# 2            3           20      10.4930       53.4155            110.53
# 3            4           20      17.0635       59.8345            140.16
# 4            5           20      12.5725       62.3685            122.16
# 5            6           20      14.1215       57.0655            111.00
# 6            7           20      12.5130       53.3975            121.38
# 7            8           20      16.3590       61.2785            142.31
#
#              timestamp
# 0  2025-09-07 19:13:38
# 1  2025-09-07 19:16:48
# 2  2025-09-07 19:22:25
# 3  2025-09-07 19:31:05
# 4  2025-09-09 22:35:10
# 5  2025-09-10 11:39:45
# 6  2025-09-10 11:48:16
# 7  2025-09-10 12:21:02
#      test_number            timestamp  duration_seconds  \
# 125            8  2025-09-10 12:21:02            142.31
# 126            8  2025-09-10 12:21:02            142.31
# 127            8  2025-09-10 12:21:02            142.31
# 128            8  2025-09-10 12:21:02            142.31
# 129            8  2025-09-10 12:21:02            142.31
# 130            8  2025-09-10 12:21:02            142.31
# 131            8  2025-09-10 12:21:02            142.31
# 132            8  2025-09-10 12:21:02            142.31
# 133            8  2025-09-10 12:21:02            142.31
# 134            8  2025-09-10 12:21:02            142.31
# 135            8  2025-09-10 12:21:02            142.31
# 136            8  2025-09-10 12:21:02            142.31
# 137            8  2025-09-10 12:21:02            142.31
# 138            8  2025-09-10 12:21:02            142.31
# 139            8  2025-09-10 12:21:02            142.31
# 140            8  2025-09-10 12:21:02            142.31
# 141            8  2025-09-10 12:21:02            142.31
# 142            8  2025-09-10 12:21:02            142.31
# 143            8  2025-09-10 12:21:02            142.31
# 144            8  2025-09-10 12:21:02            142.31
#
#                                               question  \
# 125  how many electrons will go in the first shell ...
# 126     who won the 9th season of america's got talent
# 127     has there ever been a female thunderbird pilot
# 128       what is the story of the blair witch project
# 129       when was michael jordan drafted to the bulls
# 130               when does far cry 5 for ps4 come out
# 131    section 7 of copland's appalachian spring is in
# 132      who is the oldest living person ever recorded
# 133         can a foreign born us citizen be president
# 134          rosa from orange is the new black actress
# 135          who wrote the song can't live without you
# 136  approximately what is the minimum surface temp...
# 137         what are the names of florida georgia line
# 138  where did the industrial revolution begin in t...
# 139  where is the andes mountains located in south ...
# 140        who built the temple in the sea in trinidad
# 141  what is the general name of the implement used...
# 142  what is the name of the drawings created as pa...
# 143      where is montana located in the united states
# 144             who played the orion girl in star trek
#
#                                        expected_answer  \
# 125  Electron shell Each shell can contain only a f...
# 126  America's Got Talent (season 9) Season nine of...
# 127  Nicole Malachowski Nicole Margaret Ellingwood ...
# 128  The Blair Witch Project Development of The Bla...
# 129  1984 NBA draft The Houston Rockets used their ...
# 130  Far Cry 5 Far Cry 5 is an action-adventure fir...
# 131  Appalachian Spring For many years part of the ...
# 132  List of the verified oldest people The oldest ...
# 133  Natural-born-citizen clause The U.S. Constitut...
# 134  Miss Rosa Rosa "Miss Rosa" Cisneros is a ficti...
# 135  Without You (Badfinger song) "Without You" is ...
# 136  Climate of Mars Differing in situ values have ...
# 137  Florida Georgia Line Florida Georgia Line (som...
# 138  Industrial Revolution The precise start and en...
# 139  Andes The Andes or Andean Mountains (Spanish: ...
# 140  Temple in the Sea The Temple in the Sea is a H...
# 141  Golf equipment A player usually carries severa...
# 142  Storyboard A film storyboard, commonly known a...
# 143  Montana Montana is one of the nine Mountain St...
# 144  Orion (Star Trek) The Orions are a fictional e...
#
#                                           llm_response  overlap_percent  \
# 125                                                  7             0.00
# 126  The winner of America's Got Talent's ninth sea...            38.44
# 127  Yes, there have been several female Thunderbir...             7.14
# 128  The Blair Witch Project was a found footage ho...            37.83
# 129   Michael Jordan was drafted by the Bulls in 1984.            10.97
# 130  Far Cry 5 is set to be released on October 4, ...            31.76
# 131                            The Appalachian Spring.             0.57
# 132  Jeanne Calment was the oldest living person ev...            38.36
# 133  Yes, it is possible for a foreign-born U.S. Ci...             6.88
# 134  The name "rosa" means rose in Spanish, so it d...             9.51
# 135  The lyrics "I just wanna be your everything, a...            11.11
# 136  -80.3 °C  -60.4 °C  -63.9 °C  -62.1 °C  -53.6 ...             0.20
# 137  The capital cities of Florida and Georgia are ...             2.64
# 138  The Industrial Revolution began in Britain dur...            15.11
# 139  The Andes Mountains are located on the western...            43.77
# 140  The ancient Greeks believed that Poseidon, the...            30.93
# 141  The implement used to strike the ball in golf ...             6.32
# 142  The term "storyboarding" refers to the process...            22.59
# 143                                           Montana.             0.00
# 144            Who played the Orion Girl in Star Trek?            13.05
#
#      semantic_percent
# 125             13.21
# 126             61.40
# 127             58.90
# 128             72.63
# 129             75.59
# 130             80.07
# 131             60.30
# 132             84.13
# 133             58.80
# 134             45.87
# 135             35.75
# 136             37.65
# 137             36.38
# 138             81.92
# 139             86.02
# 140             56.28
# 141             65.47
# 142             86.20
# 143             64.15
# 144             64.85

# %%
main(n=20)
